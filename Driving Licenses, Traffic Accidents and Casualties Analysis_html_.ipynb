# %% [markdown]
# ## Driving Licenses, Traffic Accidents and Casualties Analysis

# %% [markdown]
# ## Datasets Description
#
# [Driving Licenses](https://datasource.kapsarc.org/explore/dataset/saudi-arabia-driving-licenses-issued-in-the-kingdom-2004-2008/information/?disjunctive.administritive_area&sort=time_period&location=5,24.37495,45.08024&basemap=jawg.streets)
# This dataset contains Saudi Arabia Driving Licenses Issued By Administrative Area for 1993 - 2016. Data from General Authority for Statistics . Follow datasource.kapsarc.org for timely data to advance energy economics research.
#
# [Traffic Accidents and Casualties](https://datasource.kapsarc.org/explore/dataset/saudi-arabia-traffic-accidents-and-casualties-injured-dead-2008/export/?disjunctive.region&disjunctive.indicator&sort=time_period)
# This dataset contains Saudi Arabia Traffic Accidents and Casualties by Region for 2016. Data from General Authority for Statistics. Follow datasource.kapsarc.org for timely data to advance energy economics research.

# %%
#KSA_traffic df
# Out:
#    Unnamed: 0  Unnamed: 0.1    Year            Region  \
# 0           0             0  (2016)            Makkah
# 1           1             1  (2016)    Eastern Region
# 2           2             2  (2016)            Tabouk
# 3           3             3  (2016)              Hail
# 4           4             4  (2016)              Hail
# 5           5             5  (2016)  Northern Boarder
# 6           6             6  (2017)             Jazan
# 7           7             7  (2017)           Al-Jouf
# 8           8             8  (2017)             Total
# 9           9             9  (2016)  Northern Boarder
#
#                      Indicator   Value                  geo_point_2d
# 0  No. of Casualties - Injured  12383n   21.628962766, 41.2636898334
# 1     No. of Casualties - Dead   1113n  23.2883307307, 50.1478302439
# 2     No. of Casualties - Dead    434n    27.90165499, 37.2598581394
# 3     No. of Casualties - Dead    299n   27.400845724, 41.4406960508
# 4             No. of Accidents  10199n   27.400845724, 41.4406960508
# 5     No. of Casualties - Dead    193n   30.197074783, 41.8171186952
# 6             No. of Accidents  22161n  17.2072313962, 42.6525807422
# 7             No. of Accidents  10469n  29.9677445762, 39.5570371172
# 8     No. of Casualties - Dead   7489n                           NaN
# 9  No. of Casualties - Injured    631n   30.197074783, 41.8171186952

# %%
#KSA_driving df
# Out:
#    Unnamed: 0    Year Administritive Area Driving Liceses  \
# 0           0  (2012)              Makkah         143954n
# 1           1  (1994)              Makkah          75349n
# 2           2  (1998)              Makkah          86082n
# 3           3  (2004)              Makkah          86636n
# 4           4  (2005)              Makkah          65099n
# 5           5  (2008)              Makkah          77013n
# 6           6  (2014)             Madinah          31447n
# 7           7  (2013)             Madinah          28513n
# 8           8  (2012)             Madinah          14459n
# 9           9  (1994)             Madinah           3767n
#
#                   geo_point_2d
# 0  21.628962766, 41.2636898334
# 1  21.628962766, 41.2636898334
# 2  21.628962766, 41.2636898334
# 3  21.628962766, 41.2636898334
# 4  21.628962766, 41.2636898334
# 5  21.628962766, 41.2636898334
# 6  24.927534539, 39.4918237173
# 7  24.927534539, 39.4918237173
# 8  24.927534539, 39.4918237173
# 9  24.927534539, 39.4918237173

# %%
# Out:
# KSA traffic missing values:
# Unnamed: 0      0
# Unnamed: 0.1    0
# Year            0
# Region          0
# Indicator       0
# Value           0
# geo_point_2d    6
# dtype: int64
#
#  KSA drving missing values:
#  Unnamed: 0              0
# Year                    0
# Administritive Area     0
# Driving Liceses         0
# geo_point_2d           25
# dtype: int64

# %%
# Out:
# dtypes of KSA driving df are:
#  Unnamed: 0              int64
# Year                   object
# Administritive Area    object
# Driving Liceses        object
# geo_point_2d           object
# dtype: object
#
#  dtypes of KSA traffic df are:
#  Unnamed: 0       int64
# Unnamed: 0.1     int64
# Year            object
# Region          object
# Indicator       object
# Value           object
# geo_point_2d    object
# dtype: object

# %% [markdown]
# * 1- there is many columns in both datasetes need to reset the type and fix the way of which the columns' value written
#
# * 2- Accidents dataset need to be formatted to wide so we can take a good look and better way of handling it's data
#
#
# ---

# %% [markdown]
# ### Working in columns:
# 1-  **Clean  columns' values for both dfs :**
# * Removing the parentheses and the 'n' latter from both dfs.
# * Make new columns x and y using geo_point_2d
# * Drop unnecessary columns like (`'Unnamed: 0'`,`'Unnamed: 0.1'`,`'geo_point_2d'`)

# %%
KSA_driving_df
# Out:
#    Year Administritive Area Driving Liceses             y               x
# 0  2012              Makkah          143954  21.628962766   41.2636898334
# 1  1994              Makkah           75349  21.628962766   41.2636898334
# 2  1998              Makkah           86082  21.628962766   41.2636898334
# 3  2004              Makkah           86636  21.628962766   41.2636898334
# 4  2005              Makkah           65099  21.628962766   41.2636898334

# %%
KSA_traffic_df
# Out:
#    Year          Region                    Indicator  Value              y  \
# 0  2016          Makkah  No. of Casualties - Injured  12383   21.628962766
# 1  2016  Eastern Region     No. of Casualties - Dead   1113  23.2883307307
# 2  2016          Tabouk     No. of Casualties - Dead    434    27.90165499
# 3  2016            Hail     No. of Casualties - Dead    299   27.400845724
# 4  2016            Hail             No. of Accidents  10199   27.400845724
#
#                 x
# 0   41.2636898334
# 1   50.1478302439
# 2   37.2598581394
# 3   41.4406960508
# 4   41.4406960508

# %% [markdown]
# 2- **apply function that converts all numerical values  to an appropriate numeric type.**

# %%
# Out:
# dtypes of KSA traffic df:
#  Year           int64
# Region        object
# Indicator     object
# Value          int64
# y            float64
# x            float64
# dtype: object
#
#  dtypes of KSA driving df:
#  Year                     int64
# Administritive Area     object
# Driving Liceses          int64
# y                      float64
# x                      float64
# dtype: object

# %%
KSA_traffic_df
# Out:
#    Year          Region                    Indicator  Value          y  \
# 0  2016          Makkah  No. of Casualties - Injured  12383  21.628963
# 1  2016  Eastern Region     No. of Casualties - Dead   1113  23.288331
# 2  2016          Tabouk     No. of Casualties - Dead    434  27.901655
# 3  2016            Hail     No. of Casualties - Dead    299  27.400846
# 4  2016            Hail             No. of Accidents  10199  27.400846
#
#            x
# 0  41.263690
# 1  50.147830
# 2  37.259858
# 3  41.440696
# 4  41.440696

# %%
KSA_driving_df
# Out:
#    Year Administritive Area  Driving Liceses          y         x
# 0  2012              Makkah           143954  21.628963  41.26369
# 1  1994              Makkah            75349  21.628963  41.26369
# 2  1998              Makkah            86082  21.628963  41.26369
# 3  2004              Makkah            86636  21.628963  41.26369
# 4  2005              Makkah            65099  21.628963  41.26369

# %% [markdown]
# ---

# %% [markdown]
# 3- **Rename the columns to more expressive names and those names should be match for the samilaer columns in both  dfs becouse I will combining them soon.**
#
# Names should be :
# - All in lowercase.
# - Column names should not contain spaces.
# - Column names should be unique and informative.

# %%
KSA_traffic_df
# Out:
#    Year          Region            Type_of_Accidents  num_of_Accidents  \
# 0  2016          Makkah  No. of Casualties - Injured             12383
# 1  2016  Eastern Region     No. of Casualties - Dead              1113
# 2  2016          Tabouk     No. of Casualties - Dead               434
# 3  2016            Hail     No. of Casualties - Dead               299
# 4  2016            Hail             No. of Accidents             10199
#
#    longitude_y  latitude_x
# 0    21.628963   41.263690
# 1    23.288331   50.147830
# 2    27.901655   37.259858
# 3    27.400846   41.440696
# 4    27.400846   41.440696

# %%
KSA_driving_df
# Out:
#    Year  Region  Driving_Liceses  longitude_y  latitude_x
# 0  2012  Makkah           143954    21.628963    41.26369
# 1  1994  Makkah            75349    21.628963    41.26369
# 2  1998  Makkah            86082    21.628963    41.26369
# 3  2004  Makkah            86636    21.628963    41.26369
# 4  2005  Makkah            65099    21.628963    41.26369

# %% [markdown]
# ---

# %% [markdown]
# **Now all the data had been fixed we can have our data dictionary.**
# - A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions.

# %% [markdown]
# **Driving License df :**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |Year|int|Driving_Licenses|The year where the Licenses issued |
# |Region|str|Driving_Licenses| 13 region of Saudi Arabia|
# |Driving_Liceses|int|Driving_Licenses|the number of Licenses|
# |longitude_y |float|Driving_Licenses| y_Coordinate for a region|
# |latitude_x|float|Driving_Licenses|x_Coordinate for a region|

# %% [markdown]
# **Traffic Accidents df :**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |Year|int|Traffic_Accidents	|The year where the accident happend|
# |Region|str|Traffic_Accidents| 13 region of Saudi Arabia|
# |Type_of_Accidents|str|Traffic_Accidents|ether it's # of Casualties or # of  of Accidents|
# |longitude_y |float|Traffic_Accidents| y_Coordinate for a region|
# |latitude_x|float|Traffic_Accidents|x_Coordinate for a region|

# %% [markdown]
# ---

# %% [markdown]
# ### Working in the rows
#
# 1-  **Dropping unnecessary rows**
#
# **ACTION** : there is unreasonable rows in region column in both dfs named (Total), I will **drop them all**.

# %% [markdown]
# before..

# %%
#code
KSA_traffic_df #there is region named Total
# Out:
# array(['Makkah', 'Eastern Region', 'Tabouk', 'Hail', 'Northern Boarder',
#        'Jazan', 'Al-Jouf', 'Total', 'Al-Baaha', 'Riyadh', 'Madinah',
#        'Qassim', 'Najran', 'Asir'], dtype=object)

# %% [markdown]
# After droping..

# %%
KSA_traffic_df
# Out:
# array(['Makkah', 'Eastern Region', 'Tabouk', 'Hail', 'Northern Boarder',
#        'Jazan', 'Al-Jouf', 'Al-Baaha', 'Riyadh', 'Madinah', 'Qassim',
#        'Najran', 'Asir'], dtype=object)

# %% [markdown]
# - Same process for the driving df

# %% [markdown]
# After dropping..

# %%
KSA_driving_df.Region.unique()
# Out:
# array(['Makkah', 'Madinah', 'Al-Qaseem', 'Eastern', 'Assir', 'Tabouk',
#        'Hail', 'Northern Boarder', 'Jazan', 'Najran', 'Al-Baha',
#        'Al-Jouf', 'Riyadh'], dtype=object)

# %% [markdown]
# 2-  **Unmatch names for the cities in both dfs**
#
#
# |driving|traffic|
# |---|---|
# |Al-Qaseem|Qassim|
# |Eastern|Eastern Region|
# |Assir|Asir|
# |Al-Baha|Al-Baaha|
#
#
# **ACTION** : Adopt one nomanation in both dfs and use `apply` with `lambda` to apply changes.

# %% [markdown]
# Now they match..

# %%
KSA_traffic_df.Region.unique()
# Out:
# array(['Makkah', 'Eastern Region', 'Tabouk', 'Hail', 'Northern Boarder',
#        'Jazan', 'Al-Jouf', 'Al-Baha', 'Riyadh', 'Madinah', 'Al-Qaseem',
#        'Najran', 'Assir'], dtype=object)

# %%
KSA_driving_df.Region.unique()
# Out:
# array(['Makkah', 'Madinah', 'Al-Qaseem', 'Eastern Region', 'Assir',
#        'Tabouk', 'Hail', 'Northern Boarder', 'Jazan', 'Najran', 'Al-Baha',
#        'Al-Jouf', 'Riyadh'], dtype=object)

# %% [markdown]
# ---

# %% [markdown]
# * **Merge Dataframes**
#
# **ACTION**:
# - First I'll change the format for `KSA_traffic_df` to wide shape to be able to merge both dfs together.
# - Then I'll make the **region** and **year**  columns in each dfs as the keys.

# %%
traffic_wide_pv
# Out:
# Type_of_Accidents      No. of Accidents  No. of Casualties - Dead  \
# Year Region
# 2016 Al-Baha                       3618                       185
#      Al-Jouf                      10212                       245
#      Al-Qaseem                    25664                       397
#      Assir                        32684                       983
#      Eastern Region              101619                      1113
#      Hail                         10199                       299
#      Jazan                        25873                       514
#      Madinah                      14475                       822
#      Makkah                      134838                      2243
#      Najran                        3235                       173
#      Northern Boarder             13196                       193
#      Riyadh                      141736                      1430
#      Tabouk                       16031                       434
# 2017 Al-Baha                       1414                       134
#      Al-Jouf                      10469                       240
#      Al-Qaseem                    22405                       319
#      Assir                        25245                       828
#      Eastern Region               81433                       963
#      Hail                          9379                       265
#      Jazan                        22161                       466
#      Madinah                      16070                       580
#      Makkah                      145541                      1641
#      Najran                        3193                       194
#      Northern Boarder             11540                       112
#      Riyadh                       99925                      1399
#      Tabouk                       11713                       348
#
# Type_of_Accidents      No. of Casualties - Injured
# Year Region
# 2016 Al-Baha                                  1227
#      Al-Jouf                                   920
#      Al-Qaseem                                1513
#      Assir                                    2541
#      Eastern Region                           4893
#      Hail                                      932
#      Jazan                                    2259
#      Madinah                                  4184
#      Makkah                                  12383
#      Najran                                    706
#      Northern Boarder                          631
#      Riyadh                                   4207
#      Tabouk                                   1724
# 2017 Al-Baha                                  1007
#      Al-Jouf                                   862
#      Al-Qaseem                                1446
#      Assir                                    2368
#      Eastern Region                           4073
#      Hail                                      773
#      Jazan                                    2207
#      Madinah                                  2917
#      Makkah                                  10623
#      Najran                                    766
#      Northern Boarder                          374
#      Riyadh                                   4540
#      Tabouk                                   1243

# %%
merged_wide
# Out:
#    Year          Region  No_of_Accidents  No. of Casualties - Dead  \
# 0  2016         Al-Baha           3618.0                     185.0
# 1  2016         Al-Jouf          10212.0                     245.0
# 2  2016       Al-Qaseem          25664.0                     397.0
# 3  2016           Assir          32684.0                     983.0
# 4  2016  Eastern Region         101619.0                    1113.0
#
#    No. of Casualties - Injured  Driving_Liceses  longitude_y  latitude_x
# 0                       1227.0             4614    20.148406   41.466548
# 1                        920.0             9371    29.967745   39.557037
# 2                       1513.0             9180    26.196706   43.343000
# 3                       2541.0            41367    19.138785   42.941470
# 4                       4893.0           142307    23.288331   50.147830

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Out:
#                              count          mean           std          min  \
# Year                         325.0   2005.000000      7.222222  1993.000000
# No_of_Accidents               26.0  38225.692308  46493.705035  1414.000000
# No. of Casualties - Dead      26.0    635.384615    549.783381   112.000000
# No. of Casualties - Injured   26.0   2743.038462   2922.641127   374.000000
# Driving_Liceses              325.0  28915.347692  47419.058819   915.000000
# longitude_y                  325.0     23.810447      4.197987    17.207231
# latitude_x                   325.0     42.602789      3.254196    37.259858
#
#                                       25%           50%           75%  \
# Year                          1999.000000   2005.000000   2011.000000
# No_of_Accidents              10276.250000  16050.500000  30981.250000
# No. of Casualties - Dead       241.250000    415.500000    929.250000
# No. of Casualties - Injured    923.000000   1618.500000   3784.000000
# Driving_Liceses               4846.000000  10267.000000  25423.000000
# longitude_y                     20.148406     23.288331     27.400846
# latitude_x                      41.263690     41.817119     43.343000
#
#                                        max
# Year                           2017.000000
# No_of_Accidents              145541.000000
# No. of Casualties - Dead       2243.000000
# No. of Casualties - Injured   12383.000000
# Driving_Liceses              495307.000000
# longitude_y                      30.197075
# latitude_x                       50.147830

# %% [markdown]
# - **10th Regions having the highest Driving Licenses in years (1993 - 2017):**

# %%
# Out:
#      Year          Region  Driving_Liceses
# 24   2017          Riyadh           495307
# 11   2016          Riyadh           242851
# 158  2014          Riyadh           194208
# 82   2013          Riyadh           165994
# 85   2015          Makkah           157389
# 110  2011  Eastern Region           151087
# 89   2014          Makkah           149234
# 26   2012          Makkah           143954
# 21   2017          Makkah           142487
# 4    2016  Eastern Region           142307

# %% [markdown]
# - **10th Regions having the smallest Driving Licenses in years (1993 - 2017):**

# %%
# Out:
#      Year            Region  Driving_Liceses
# 205  2015            Tabouk              915
# 177  2007           Al-Baha              997
# 266  1995  Northern Boarder             1318
# 164  1996  Northern Boarder             1383
# 267  1994  Northern Boarder             1457
# 76   1996           Al-Baha             1468
# 58   1993  Northern Boarder             1510
# 268  1997  Northern Boarder             1531
# 214  2003  Northern Boarder             1705
# 60   2005  Northern Boarder             1804

# %% [markdown]
# ---

# %% [markdown]
#  - Regions have the highest mean Traffic Accidents numbers for years (2016 - 2017):
#     - Find the mean number of accidents in 2016.
#     - Find the mean number of accidents in 2017.
#     - Merge them in one df.
#     - Search for lagre and small mean in all regions smothly in one df  for both years.

# %%
df_mean_016_017
# Out:
#            Region mean_accidents_2016 mean_accidents_2017
#
# 0         Al-Baha              3618.0              1414.0
# 1         Al-Jouf             10212.0             10469.0
# 2       Al-Qaseem             25664.0             22405.0
# 3           Assir             32684.0             25245.0
# 4  Eastern Region            101619.0             81433.0

# %% [markdown]
# * Largest mean accidents in 2017 :

# %%
# Out:
#    Region mean_accidents_2017
#
# 8  Makkah            145541.0

# %% [markdown]
# * Largest mean accidents in 2016 :

# %%
# Out:
#     Region mean_accidents_2016
#
# 11  Riyadh            141736.0

# %% [markdown]
# * Smallest mean accidents in 2017 :

# %%
# Out:
#     Region mean_accidents_2017
#
# 0  Al-Baha              1414.0

# %% [markdown]
# * Smallest mean accidents in 2016:

# %%
# Out:
#    Region mean_accidents_2016
#
# 9  Najran              3235.0

# %% [markdown]
# ---
# * Regions having more Driving Licenses issued in each year than the year average
#    - calculate the mean driving licenes for each region.

# %%
final_df
# Out:
#      Year     Region  Driving_Liceses       DL_mean
# 155  1993     Riyadh           103886  22684.076923
# 183  1993     Makkah            65977  22684.076923
# 301  1993  Al-Qaseem            73618  22684.076923
# 105  1994  Al-Qaseem            68916  23347.692308
# 27   1994     Makkah            75349  23347.692308

# %% [markdown]
# ## Visualize the data

# %% [markdown]
# Histograms of:
# - Driving Licenses number
# - Traffic Accidents number

# %%
# Out:
# C:\Users\hsfd\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\hsfd\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# #### Driving Licenses vs. Traffic Accidents for 2017

# %% [markdown]
# **Exclude the outliers**

# %% [markdown]
# #### Driving Licenses vs. Traffic Accidents for 2016

# %% [markdown]
# **Exclude the outliers**

# %% [markdown]
# #### Driving Licenses for 2016 vs 2017

# %% [markdown]
# #### Traffic Accidents for 2016 vs 2017

# %% [markdown]
# #### Plot and interpret boxplots
# - Scale the values just to make them all in the same magnitude.
# - plot the new scaled df.
#    - plot all numerical variables.
#    - plot Number of Casualties - Dead for each region.
#    - plot Number of Accidents for each region.
#    - plot Number of Driving License issued for each region.
